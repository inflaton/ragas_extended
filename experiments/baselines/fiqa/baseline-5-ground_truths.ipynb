# %% [markdown]
# # Bring your own LLMs
#
# Ragas uses langchain under the hood for connecting to LLMs for metrices that require them. This means you can swap out the default LLM we use (`gpt-3.5-turbo-16k`) to use any 100s of API supported out of the box with langchain.
#
# - [Completion LLMs Supported](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.llms)
# - [Chat based LLMs Supported](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.chat_models)
#
# This guide will show you how to use another or LLM API for evaluation.

# %% [markdown]
# ## Evaluating with GPT-3.5-turbo-instruct

# %%
# %pip show ragas
# Out:
# Name: ragas
# Version: 0.0.15.dev2+gd590b10.d20230924
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /Users/inflaton/miniconda3/lib/python3.10/site-packages
# Requires: datasets, langchain, numpy, openai, pydantic, pysbd, sentence-transformers, transformers
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# data
from datasets import load_dataset

fiqa_eval = load_dataset("explodinggradients/fiqa", "ragas_eval")
fiqa_eval
# Out:
# DatasetDict({
#     baseline: Dataset({
#         features: ['question', 'ground_truths', 'answer', 'contexts'],
#         num_rows: 30
#     })
# })

# %%
pruned_index = [1,  2,  3,  7,  9, 10, 12, 13, 14, 15, 18, 19, 21, 22, 23, 24, 25, 26, 27, 28]
pruned_ds = fiqa_eval["baseline"].select(pruned_index)
pruned_ds.to_pandas()
# Out:
#                                              question  \
# 0   Can I send a money order from USPS as a business?
# 1   1 EIN doing business under multiple business n...
# 2          Applying for and receiving business credit
# 3   Intentions of Deductible Amount for Small Busi...
# 4   Filing personal with 1099s versus business s-c...
# 5   Using credit card points to pay for tax deduct...
# 6   Investing/business with other people's money: ...
# 7   What approaches are there for pricing a small ...
# 8   How to account for money earned and spent prio...
# 9   Do I need a new EIN since I am hiring employee...
# 10  financial institution wants share member break...
# 11                        Sole proprietorship or LLC?
# 12  Where to request ACH Direct DEBIT of funds fro...
# 13  Challenged an apparently bogus credit card cha...
# 14  Employer options when setting up 401k for empl...
# 15          Following an investment guru a good idea?
# 16          Is there a reason to buy a 0% yield bond?
# 17  Should a retail trader bother about reading SE...
# 18  Will one’s education loan application be rejec...
# 19  Is there a dollar amount that, when adding Mas...
#
#                                         ground_truths  \
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   ["I'm afraid the great myth of limited liabili...
# 3   ["If your sole proprietorship losses exceed al...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [I called the IRS (click here for IRS contact ...
# 10  ["What exactly would the financial institution...
# 11  ["The primary advantage is protection of your ...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [Yes.  For $15 it's not worth anyone's time to...
# 14  [If you were looking to maximize your ability ...
# 15  ["The best answer here is ""maybe, but probabl...
# 16  [0% bonds are desirable for some individuals. ...
# 17  ["There are many different kinds of SEC filing...
# 18  [A bank can reject a loan if they feel you do ...
# 19  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...
#
#                                                answer  \
# 0   \nYes, you can send a money order from USPS as...
# 1   \nYes, it is possible to have one EIN doing bu...
# 2   \nApplying for and receiving business credit c...
# 3   \nThe intention of deductible amounts for smal...
# 4   \nFiling personal taxes with 1099s versus fili...
# 5   \nUsing credit card points to pay for tax dedu...
# 6   \nInvesting/business with other people's money...
# 7   \nThere are several approaches for pricing a s...
# 8   \nMoney earned and spent prior to establishing...
# 9   \nNo, you do not need a new EIN since you are ...
# 10  \nThe financial institution would need to see ...
# 11  \nIt depends on your individual situation and ...
# 12  \nThe best place to request ACH Direct DEBIT o...
# 13  \nNow, the collector is obliged to go back to ...
# 14  \nWhen setting up a 401k plan for employees, e...
# 15  \nNo, following an investment guru is not nece...
# 16  \nYes, there is a reason to buy a 0% yield bon...
# 17  \nIt depends on the individual investor's goal...
# 18  \nIt is possible that one's education loan app...
# 19  \nNo, there is not a dollar amount that, when ...
#
#                                              contexts
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   [Set up a meeting with the bank that handles y...
# 3   ["Short answer, yes. But this is not done thro...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [You don't need to notify the IRS of new membe...
# 10  ["What exactly would the financial institution...
# 11  [There is some benefit to creating a corporati...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [If you tell the collector that the claim isn'...
# 14  [Pre-Enron many companies forced the 401K matc...
# 15  [I think following the professional money mana...
# 16  [No, there isn't. There are a number of reason...
# 17  ["There are many different kinds of SEC filing...
# 18  [Edit: lazy math The answer to this question d...
# 19  [Yes, it's a simple calculation. (x+0.0625x)=2...

# %%
pruned_ds.to_csv("pruned-ds.csv", sep='\t')
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 100872

# %%
"""
Official evaluation script for QAConv, modified from SQuAD 2.0.

 * Copyright (c) 2021, salesforce.com, inc.
 * All rights reserved.
 * SPDX-License-Identifier: BSD-3-Clause
 * For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

"""

import collections
import re
import string


def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def get_tokens(s):
    if not s:
        return []
    return normalize_answer(s).split()


def compute_exact(a_gold, a_pred):
    return int(normalize_answer(a_gold) == normalize_answer(a_pred))


def compute_f1(a_gold, a_pred):
    gold_toks = get_tokens(a_gold)
    pred_toks = get_tokens(a_pred)
    common = collections.Counter(gold_toks) & collections.Counter(pred_toks)
    num_same = sum(common.values())
    if len(gold_toks) == 0 or len(pred_toks) == 0:
        # If either is no-answer, then F1 is 1 if they agree, 0 otherwise
        return int(gold_toks == pred_toks)
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(pred_toks)
    recall = 1.0 * num_same / len(gold_toks)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1

# %%
cut_off_at =  5 # dataset.num_rows
new_ds = pruned_ds.map(
    lambda record, idx: {
        "answer": record["ground_truths"][0] if idx < cut_off_at else  record["answer"],
        "EM": compute_exact(record['ground_truths'][0], record["ground_truths"][0] if idx < cut_off_at else record["answer"]), 
        "F1": compute_f1(record['ground_truths'][0], record["ground_truths"][0] if idx < cut_off_at else record["answer"])
    },
    batched=False,
    with_indices=True,
)
new_ds
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'ground_truths', 'answer', 'contexts', 'EM', 'F1'],
#     num_rows: 20
# })

# %%
new_ds.to_pandas()
# Out:
#                                              question  \
# 0   Can I send a money order from USPS as a business?
# 1   1 EIN doing business under multiple business n...
# 2          Applying for and receiving business credit
# 3   Intentions of Deductible Amount for Small Busi...
# 4   Filing personal with 1099s versus business s-c...
# 5   Using credit card points to pay for tax deduct...
# 6   Investing/business with other people's money: ...
# 7   What approaches are there for pricing a small ...
# 8   How to account for money earned and spent prio...
# 9   Do I need a new EIN since I am hiring employee...
# 10  financial institution wants share member break...
# 11                        Sole proprietorship or LLC?
# 12  Where to request ACH Direct DEBIT of funds fro...
# 13  Challenged an apparently bogus credit card cha...
# 14  Employer options when setting up 401k for empl...
# 15          Following an investment guru a good idea?
# 16          Is there a reason to buy a 0% yield bond?
# 17  Should a retail trader bother about reading SE...
# 18  Will one’s education loan application be rejec...
# 19  Is there a dollar amount that, when adding Mas...
#
#                                         ground_truths  \
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   ["I'm afraid the great myth of limited liabili...
# 3   ["If your sole proprietorship losses exceed al...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [I called the IRS (click here for IRS contact ...
# 10  ["What exactly would the financial institution...
# 11  ["The primary advantage is protection of your ...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [Yes.  For $15 it's not worth anyone's time to...
# 14  [If you were looking to maximize your ability ...
# 15  ["The best answer here is ""maybe, but probabl...
# 16  [0% bonds are desirable for some individuals. ...
# 17  ["There are many different kinds of SEC filing...
# 18  [A bank can reject a loan if they feel you do ...
# 19  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...
#
#                                                answer  \
# 0   Sure you can.  You can fill in whatever you wa...
# 1   You're confusing a lot of things here. Company...
# 2   "I'm afraid the great myth of limited liabilit...
# 3   "If your sole proprietorship losses exceed all...
# 4   Depends whom the 1099 was issued to. If it was...
# 5   \nUsing credit card points to pay for tax dedu...
# 6   \nInvesting/business with other people's money...
# 7   \nThere are several approaches for pricing a s...
# 8   \nMoney earned and spent prior to establishing...
# 9   \nNo, you do not need a new EIN since you are ...
# 10  \nThe financial institution would need to see ...
# 11  \nIt depends on your individual situation and ...
# 12  \nThe best place to request ACH Direct DEBIT o...
# 13  \nNow, the collector is obliged to go back to ...
# 14  \nWhen setting up a 401k plan for employees, e...
# 15  \nNo, following an investment guru is not nece...
# 16  \nYes, there is a reason to buy a 0% yield bon...
# 17  \nIt depends on the individual investor's goal...
# 18  \nIt is possible that one's education loan app...
# 19  \nNo, there is not a dollar amount that, when ...
#
#                                              contexts  EM        F1
# 0   [Sure you can.  You can fill in whatever you w...   1  1.000000
# 1   [You're confusing a lot of things here. Compan...   1  1.000000
# 2   [Set up a meeting with the bank that handles y...   1  1.000000
# 3   ["Short answer, yes. But this is not done thro...   1  1.000000
# 4   [Depends whom the 1099 was issued to. If it wa...   1  1.000000
# 5   ["For simplicity, let's start by just consider...   0  0.199367
# 6   ["Basically, you either borrow money, or get o...   0  0.356436
# 7   [I don't have any experience in this, but this...   0  0.383495
# 8   [Funds earned and spent before opening a dedic...   0  0.671642
# 9   [You don't need to notify the IRS of new membe...   0  0.331288
# 10  ["What exactly would the financial institution...   0  0.596273
# 11  [There is some benefit to creating a corporati...   0  0.267606
# 12  [Call Wells Fargo or go to a branch.  Tell the...   0  0.353982
# 13  [If you tell the collector that the claim isn'...   0  0.423913
# 14  [Pre-Enron many companies forced the 401K matc...   0  0.219780
# 15  [I think following the professional money mana...   0  0.443114
# 16  [No, there isn't. There are a number of reason...   0  0.276596
# 17  ["There are many different kinds of SEC filing...   0  0.214000
# 18  [Edit: lazy math The answer to this question d...   0  0.225352
# 19  [Yes, it's a simple calculation. (x+0.0625x)=2...   0  0.054054

# %%
# %%time
# evaluate
from ragas import evaluate
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
)

result = evaluate(
    new_ds,
    metrics=[
        faithfulness,
        answer_relevancy,
    ],
)

result
# Out:
# using model: gpt-3.5-turbo-instruct
# evaluating with [faithfulness]
# 100%|██████████| 2/2 [00:13<00:00,  6.73s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [00:40<00:00, 20.13s/it]
# CPU times: user 4.18 s, sys: 1.02 s, total: 5.2 s
# Wall time: 1min 14s
# {'ragas_score': 0.8096, 'faithfulness': 0.7795, 'answer_relevancy': 0.8422}

# %%
df = result.to_pandas()
df
# Out:
#                                              question  \
# 0   How to deposit a cheque issued to an associate...
# 1   Can I send a money order from USPS as a business?
# 2   1 EIN doing business under multiple business n...
# 3          Applying for and receiving business credit
# 4                401k Transfer After Business Closure
# 5   What are the ins/outs of writing equipment pur...
# 6   Can a entrepreneur hire a self-employed busine...
# 7   Intentions of Deductible Amount for Small Busi...
# 8   How can I deposit a check made out to my busin...
# 9   Filing personal with 1099s versus business s-c...
# 10  Using credit card points to pay for tax deduct...
# 11  How can I make $250,000.00 from trading/invest...
# 12  Investing/business with other people's money: ...
# 13  What approaches are there for pricing a small ...
# 14  How to account for money earned and spent prio...
# 15  Do I need a new EIN since I am hiring employee...
# 16       Privacy preferences on creditworthiness data
# 17            Have plenty of cash flow but bad credit
# 18  financial institution wants share member break...
# 19                        Sole proprietorship or LLC?
# 20  What percentage of my company should I have if...
# 21  Where to request ACH Direct DEBIT of funds fro...
# 22  Challenged an apparently bogus credit card cha...
# 23  Employer options when setting up 401k for empl...
# 24          Following an investment guru a good idea?
# 25          Is there a reason to buy a 0% yield bond?
# 26  Should a retail trader bother about reading SE...
# 27  Will one’s education loan application be rejec...
# 28  Is there a dollar amount that, when adding Mas...
# 29  Is it wise to have plenty of current accounts ...
#
#                                              contexts  \
# 0   [Just have the associate sign the back and the...
# 1   [Sure you can.  You can fill in whatever you w...
# 2   [You're confusing a lot of things here. Compan...
# 3   [Set up a meeting with the bank that handles y...
# 4   [The time horizon for your 401K/IRA is essenti...
# 5   [You would report it as business income on Sch...
# 6   [Yes. I can by all means start my own company ...
# 7   ["Short answer, yes. But this is not done thro...
# 8   ["I have checked with Bank of America, and the...
# 9   [Depends whom the 1099 was issued to. If it wa...
# 10  ["For simplicity, let's start by just consider...
# 11  ["The answer to your question is Forex trading...
# 12  ["Basically, you either borrow money, or get o...
# 13  [I don't have any experience in this, but this...
# 14  [Funds earned and spent before opening a dedic...
# 15  [You don't need to notify the IRS of new membe...
# 16  [See the first item in the list: For our every...
# 17  [This is probably a good time to note that cre...
# 18  ["What exactly would the financial institution...
# 19  [There is some benefit to creating a corporati...
# 20  [To me it depends on things like your net wort...
# 21  [Call Wells Fargo or go to a branch.  Tell the...
# 22  [If you tell the collector that the claim isn'...
# 23  [Pre-Enron many companies forced the 401K matc...
# 24  [I think following the professional money mana...
# 25  [No, there isn't. There are a number of reason...
# 26  ["There are many different kinds of SEC filing...
# 27  [Edit: lazy math The answer to this question d...
# 28  [Yes, it's a simple calculation. (x+0.0625x)=2...
# 29  [I don't think there's any law against having ...
#
#                                                answer  \
# 0   Have the check reissued to the proper payee.Ju...
# 1   Sure you can.  You can fill in whatever you wa...
# 2   You're confusing a lot of things here. Company...
# 3   "I'm afraid the great myth of limited liabilit...
# 4   You should probably consult an attorney. Howev...
# 5   Most items used in business have to be depreci...
# 6   Yes. I can by all means start my own company a...
# 7   "If your sole proprietorship losses exceed all...
# 8   You should have a separate business account. M...
# 9   Depends whom the 1099 was issued to. If it was...
# 10  "For simplicity, let's start by just consideri...
# 11  Deposit $3,500 each month in a brokerage accou...
# 12  "Basically, you either borrow money, or get ot...
# 13  I don't have any experience in this, but this ...
# 14  Funds earned and spent before opening a dedica...
# 15  I called the IRS (click here for IRS contact i...
# 16  See the first item in the list: For our everyd...
# 17  Set up a meeting with the bank that handles yo...
# 18  "What exactly would the financial institution ...
# 19  "The primary advantage is protection of your p...
# 20  There is no universal answer here; it depends ...
# 21  Call Wells Fargo or go to a branch.  Tell them...
# 22  Yes.  For $15 it's not worth anyone's time to ...
# 23  If you were looking to maximize your ability t...
# 24  "The best answer here is ""maybe, but probably...
# 25  0% bonds are desirable for some individuals. I...
# 26  "There are many different kinds of SEC filings...
# 27  A bank can reject a loan if they feel you do n...
# 28  No. $188.23 has $11.76 tax = $199.99 $188.24 h...
# 29  Its actually a good thing.  The #1 factor to y...
#
#                                         ground_truths  faithfulness  \
# 0   [Have the check reissued to the proper payee.J...      0.714286
# 1   [Sure you can.  You can fill in whatever you w...      1.000000
# 2   [You're confusing a lot of things here. Compan...      1.000000
# 3   ["I'm afraid the great myth of limited liabili...      1.000000
# 4   [You should probably consult an attorney. Howe...      0.000000
# 5   [Most items used in business have to be deprec...      0.600000
# 6   [Yes. I can by all means start my own company ...      0.500000
# 7   ["If your sole proprietorship losses exceed al...      1.000000
# 8   [You should have a separate business account. ...      0.733333
# 9   [Depends whom the 1099 was issued to. If it wa...      1.000000
# 10  ["For simplicity, let's start by just consider...      1.000000
# 11  [Deposit $3,500 each month in a brokerage acco...      0.333333
# 12  ["Basically, you either borrow money, or get o...      1.000000
# 13  [I don't have any experience in this, but this...      1.000000
# 14  [Funds earned and spent before opening a dedic...      1.000000
# 15  [I called the IRS (click here for IRS contact ...      1.000000
# 16  [See the first item in the list: For our every...      0.250000
# 17  [Set up a meeting with the bank that handles y...      0.285714
# 18  ["What exactly would the financial institution...      0.833333
# 19  ["The primary advantage is protection of your ...      0.800000
# 20  [There is no universal answer here; it depends...      0.400000
# 21  [Call Wells Fargo or go to a branch.  Tell the...      0.666667
# 22  [Yes.  For $15 it's not worth anyone's time to...      1.000000
# 23  [If you were looking to maximize your ability ...      0.800000
# 24  ["The best answer here is ""maybe, but probabl...      1.000000
# 25  [0% bonds are desirable for some individuals. ...      0.857143
# 26  ["There are many different kinds of SEC filing...      1.000000
# 27  [A bank can reject a loan if they feel you do ...      1.000000
# 28  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...      0.833333
# 29  [Its actually a good thing.  The #1 factor to ...      0.777778
#
#     answer_relevancy
# 0           0.867710
# 1           0.843422
# 2           0.798575
# 3           0.824579
# 4           0.847144
# 5           0.844843
# 6           0.860921
# 7           0.766336
# 8           0.872240
# 9           0.855224
# 10          0.861972
# 11          0.803913
# 12          0.875814
# 13          0.838752
# 14          0.907660
# 15          0.800659
# 16          0.825136
# 17          0.819634
# 18          0.834307
# 19          0.865435
# 20          0.792841
# 21          0.833629
# 22          0.864606
# 23          0.844164
# 24          0.842341
# 25          0.902724
# 26          0.859393
# 27          0.821627
# 28          0.826040
# 29          0.863358

# %%
pruned = df[df.faithfulness > 0.6]
pruned
# Out:
#                                              question  \
# 0   How to deposit a cheque issued to an associate...
# 1   Can I send a money order from USPS as a business?
# 2   1 EIN doing business under multiple business n...
# 3          Applying for and receiving business credit
# 7   Intentions of Deductible Amount for Small Busi...
# 8   How can I deposit a check made out to my busin...
# 9   Filing personal with 1099s versus business s-c...
# 10  Using credit card points to pay for tax deduct...
# 12  Investing/business with other people's money: ...
# 13  What approaches are there for pricing a small ...
# 14  How to account for money earned and spent prio...
# 15  Do I need a new EIN since I am hiring employee...
# 18  financial institution wants share member break...
# 19                        Sole proprietorship or LLC?
# 21  Where to request ACH Direct DEBIT of funds fro...
# 22  Challenged an apparently bogus credit card cha...
# 23  Employer options when setting up 401k for empl...
# 24          Following an investment guru a good idea?
# 25          Is there a reason to buy a 0% yield bond?
# 26  Should a retail trader bother about reading SE...
# 27  Will one’s education loan application be rejec...
# 28  Is there a dollar amount that, when adding Mas...
# 29  Is it wise to have plenty of current accounts ...
#
#                                              contexts  \
# 0   [Just have the associate sign the back and the...
# 1   [Sure you can.  You can fill in whatever you w...
# 2   [You're confusing a lot of things here. Compan...
# 3   [Set up a meeting with the bank that handles y...
# 7   ["Short answer, yes. But this is not done thro...
# 8   ["I have checked with Bank of America, and the...
# 9   [Depends whom the 1099 was issued to. If it wa...
# 10  ["For simplicity, let's start by just consider...
# 12  ["Basically, you either borrow money, or get o...
# 13  [I don't have any experience in this, but this...
# 14  [Funds earned and spent before opening a dedic...
# 15  [You don't need to notify the IRS of new membe...
# 18  ["What exactly would the financial institution...
# 19  [There is some benefit to creating a corporati...
# 21  [Call Wells Fargo or go to a branch.  Tell the...
# 22  [If you tell the collector that the claim isn'...
# 23  [Pre-Enron many companies forced the 401K matc...
# 24  [I think following the professional money mana...
# 25  [No, there isn't. There are a number of reason...
# 26  ["There are many different kinds of SEC filing...
# 27  [Edit: lazy math The answer to this question d...
# 28  [Yes, it's a simple calculation. (x+0.0625x)=2...
# 29  [I don't think there's any law against having ...
#
#                                                answer  \
# 0   Have the check reissued to the proper payee.Ju...
# 1   Sure you can.  You can fill in whatever you wa...
# 2   You're confusing a lot of things here. Company...
# 3   "I'm afraid the great myth of limited liabilit...
# 7   "If your sole proprietorship losses exceed all...
# 8   You should have a separate business account. M...
# 9   Depends whom the 1099 was issued to. If it was...
# 10  "For simplicity, let's start by just consideri...
# 12  "Basically, you either borrow money, or get ot...
# 13  I don't have any experience in this, but this ...
# 14  Funds earned and spent before opening a dedica...
# 15  I called the IRS (click here for IRS contact i...
# 18  "What exactly would the financial institution ...
# 19  "The primary advantage is protection of your p...
# 21  Call Wells Fargo or go to a branch.  Tell them...
# 22  Yes.  For $15 it's not worth anyone's time to ...
# 23  If you were looking to maximize your ability t...
# 24  "The best answer here is ""maybe, but probably...
# 25  0% bonds are desirable for some individuals. I...
# 26  "There are many different kinds of SEC filings...
# 27  A bank can reject a loan if they feel you do n...
# 28  No. $188.23 has $11.76 tax = $199.99 $188.24 h...
# 29  Its actually a good thing.  The #1 factor to y...
#
#                                         ground_truths  faithfulness  \
# 0   [Have the check reissued to the proper payee.J...      0.714286
# 1   [Sure you can.  You can fill in whatever you w...      1.000000
# 2   [You're confusing a lot of things here. Compan...      1.000000
# 3   ["I'm afraid the great myth of limited liabili...      1.000000
# 7   ["If your sole proprietorship losses exceed al...      1.000000
# 8   [You should have a separate business account. ...      0.733333
# 9   [Depends whom the 1099 was issued to. If it wa...      1.000000
# 10  ["For simplicity, let's start by just consider...      1.000000
# 12  ["Basically, you either borrow money, or get o...      1.000000
# 13  [I don't have any experience in this, but this...      1.000000
# 14  [Funds earned and spent before opening a dedic...      1.000000
# 15  [I called the IRS (click here for IRS contact ...      1.000000
# 18  ["What exactly would the financial institution...      0.833333
# 19  ["The primary advantage is protection of your ...      0.800000
# 21  [Call Wells Fargo or go to a branch.  Tell the...      0.666667
# 22  [Yes.  For $15 it's not worth anyone's time to...      1.000000
# 23  [If you were looking to maximize your ability ...      0.800000
# 24  ["The best answer here is ""maybe, but probabl...      1.000000
# 25  [0% bonds are desirable for some individuals. ...      0.857143
# 26  ["There are many different kinds of SEC filing...      1.000000
# 27  [A bank can reject a loan if they feel you do ...      1.000000
# 28  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...      0.833333
# 29  [Its actually a good thing.  The #1 factor to ...      0.777778
#
#     answer_relevancy
# 0           0.867710
# 1           0.843422
# 2           0.798575
# 3           0.824579
# 7           0.766336
# 8           0.872240
# 9           0.855224
# 10          0.861972
# 12          0.875814
# 13          0.838752
# 14          0.907660
# 15          0.800659
# 18          0.834307
# 19          0.865435
# 21          0.833629
# 22          0.864606
# 23          0.844164
# 24          0.842341
# 25          0.902724
# 26          0.859393
# 27          0.821627
# 28          0.826040
# 29          0.863358

# %%
pruned.index
# Out:
# Int64Index([ 0,  1,  2,  3,  7,  8,  9, 10, 12, 13, 14, 15, 18, 19, 21, 22, 23,
#             24, 25, 26, 27, 28, 29],
#            dtype='int64')

# %%
pruned_index = [1,  2,  3,  7,  9, 10, 12, 13, 14, 15, 18, 19, 21, 22, 23, 24, 25, 26, 27, 28]
pruned_ds = new_ds.select(pruned_index)
pruned_ds.to_pandas()
# Out:
#                                              question  \
# 0   Can I send a money order from USPS as a business?
# 1   1 EIN doing business under multiple business n...
# 2          Applying for and receiving business credit
# 3   Intentions of Deductible Amount for Small Busi...
# 4   Filing personal with 1099s versus business s-c...
# 5   Using credit card points to pay for tax deduct...
# 6   Investing/business with other people's money: ...
# 7   What approaches are there for pricing a small ...
# 8   How to account for money earned and spent prio...
# 9   Do I need a new EIN since I am hiring employee...
# 10  financial institution wants share member break...
# 11                        Sole proprietorship or LLC?
# 12  Where to request ACH Direct DEBIT of funds fro...
# 13  Challenged an apparently bogus credit card cha...
# 14  Employer options when setting up 401k for empl...
# 15          Following an investment guru a good idea?
# 16          Is there a reason to buy a 0% yield bond?
# 17  Should a retail trader bother about reading SE...
# 18  Will one’s education loan application be rejec...
# 19  Is there a dollar amount that, when adding Mas...
#
#                                         ground_truths  \
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   ["I'm afraid the great myth of limited liabili...
# 3   ["If your sole proprietorship losses exceed al...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [I called the IRS (click here for IRS contact ...
# 10  ["What exactly would the financial institution...
# 11  ["The primary advantage is protection of your ...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [Yes.  For $15 it's not worth anyone's time to...
# 14  [If you were looking to maximize your ability ...
# 15  ["The best answer here is ""maybe, but probabl...
# 16  [0% bonds are desirable for some individuals. ...
# 17  ["There are many different kinds of SEC filing...
# 18  [A bank can reject a loan if they feel you do ...
# 19  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...
#
#                                                answer  \
# 0   Sure you can.  You can fill in whatever you wa...
# 1   You're confusing a lot of things here. Company...
# 2   "I'm afraid the great myth of limited liabilit...
# 3   "If your sole proprietorship losses exceed all...
# 4   Depends whom the 1099 was issued to. If it was...
# 5   "For simplicity, let's start by just consideri...
# 6   "Basically, you either borrow money, or get ot...
# 7   I don't have any experience in this, but this ...
# 8   Funds earned and spent before opening a dedica...
# 9   I called the IRS (click here for IRS contact i...
# 10  "What exactly would the financial institution ...
# 11  "The primary advantage is protection of your p...
# 12  Call Wells Fargo or go to a branch.  Tell them...
# 13  Yes.  For $15 it's not worth anyone's time to ...
# 14  If you were looking to maximize your ability t...
# 15  "The best answer here is ""maybe, but probably...
# 16  0% bonds are desirable for some individuals. I...
# 17  "There are many different kinds of SEC filings...
# 18  A bank can reject a loan if they feel you do n...
# 19  No. $188.23 has $11.76 tax = $199.99 $188.24 h...
#
#                                              contexts  EM   F1
# 0   [Sure you can.  You can fill in whatever you w...   1  1.0
# 1   [You're confusing a lot of things here. Compan...   1  1.0
# 2   [Set up a meeting with the bank that handles y...   1  1.0
# 3   ["Short answer, yes. But this is not done thro...   1  1.0
# 4   [Depends whom the 1099 was issued to. If it wa...   1  1.0
# 5   ["For simplicity, let's start by just consider...   1  1.0
# 6   ["Basically, you either borrow money, or get o...   1  1.0
# 7   [I don't have any experience in this, but this...   1  1.0
# 8   [Funds earned and spent before opening a dedic...   1  1.0
# 9   [You don't need to notify the IRS of new membe...   1  1.0
# 10  ["What exactly would the financial institution...   1  1.0
# 11  [There is some benefit to creating a corporati...   1  1.0
# 12  [Call Wells Fargo or go to a branch.  Tell the...   1  1.0
# 13  [If you tell the collector that the claim isn'...   1  1.0
# 14  [Pre-Enron many companies forced the 401K matc...   1  1.0
# 15  [I think following the professional money mana...   1  1.0
# 16  [No, there isn't. There are a number of reason...   1  1.0
# 17  ["There are many different kinds of SEC filing...   1  1.0
# 18  [Edit: lazy math The answer to this question d...   1  1.0
# 19  [Yes, it's a simple calculation. (x+0.0625x)=2...   1  1.0

# %%
# %%time
# evaluate
from ragas import evaluate
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
)

pruned_result = evaluate(
    pruned_ds,
    metrics=[
        faithfulness,
        answer_relevancy,
    ],
)

pruned_result
# Out:
# evaluating with [faithfulness]
# 100%|██████████| 2/2 [00:11<00:00,  5.52s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [00:23<00:00, 11.92s/it]
# CPU times: user 329 ms, sys: 68 ms, total: 397 ms
# Wall time: 35.5 s
# {'ragas_score': 0.8849, 'faithfulness': 0.9295, 'answer_relevancy': 0.8443}

# %%
df = pruned_result.to_pandas()
df
# Out:
#                                              question  \
# 0   Can I send a money order from USPS as a business?
# 1   1 EIN doing business under multiple business n...
# 2          Applying for and receiving business credit
# 3   Intentions of Deductible Amount for Small Busi...
# 4   Filing personal with 1099s versus business s-c...
# 5   Using credit card points to pay for tax deduct...
# 6   Investing/business with other people's money: ...
# 7   What approaches are there for pricing a small ...
# 8   How to account for money earned and spent prio...
# 9   Do I need a new EIN since I am hiring employee...
# 10  financial institution wants share member break...
# 11                        Sole proprietorship or LLC?
# 12  Where to request ACH Direct DEBIT of funds fro...
# 13  Challenged an apparently bogus credit card cha...
# 14  Employer options when setting up 401k for empl...
# 15          Following an investment guru a good idea?
# 16          Is there a reason to buy a 0% yield bond?
# 17  Should a retail trader bother about reading SE...
# 18  Will one’s education loan application be rejec...
# 19  Is there a dollar amount that, when adding Mas...
#
#                                              contexts  \
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   [Set up a meeting with the bank that handles y...
# 3   ["Short answer, yes. But this is not done thro...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [You don't need to notify the IRS of new membe...
# 10  ["What exactly would the financial institution...
# 11  [There is some benefit to creating a corporati...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [If you tell the collector that the claim isn'...
# 14  [Pre-Enron many companies forced the 401K matc...
# 15  [I think following the professional money mana...
# 16  [No, there isn't. There are a number of reason...
# 17  ["There are many different kinds of SEC filing...
# 18  [Edit: lazy math The answer to this question d...
# 19  [Yes, it's a simple calculation. (x+0.0625x)=2...
#
#                                                answer  \
# 0   Sure you can.  You can fill in whatever you wa...
# 1   You're confusing a lot of things here. Company...
# 2   "I'm afraid the great myth of limited liabilit...
# 3   "If your sole proprietorship losses exceed all...
# 4   Depends whom the 1099 was issued to. If it was...
# 5   "For simplicity, let's start by just consideri...
# 6   "Basically, you either borrow money, or get ot...
# 7   I don't have any experience in this, but this ...
# 8   Funds earned and spent before opening a dedica...
# 9   I called the IRS (click here for IRS contact i...
# 10  "What exactly would the financial institution ...
# 11  "The primary advantage is protection of your p...
# 12  Call Wells Fargo or go to a branch.  Tell them...
# 13  Yes.  For $15 it's not worth anyone's time to ...
# 14  If you were looking to maximize your ability t...
# 15  "The best answer here is ""maybe, but probably...
# 16  0% bonds are desirable for some individuals. I...
# 17  "There are many different kinds of SEC filings...
# 18  A bank can reject a loan if they feel you do n...
# 19  No. $188.23 has $11.76 tax = $199.99 $188.24 h...
#
#                                         ground_truths  faithfulness  \
# 0   [Sure you can.  You can fill in whatever you w...      1.000000
# 1   [You're confusing a lot of things here. Compan...      1.000000
# 2   ["I'm afraid the great myth of limited liabili...      1.000000
# 3   ["If your sole proprietorship losses exceed al...      1.000000
# 4   [Depends whom the 1099 was issued to. If it wa...      1.000000
# 5   ["For simplicity, let's start by just consider...      1.000000
# 6   ["Basically, you either borrow money, or get o...      0.833333
# 7   [I don't have any experience in this, but this...      1.000000
# 8   [Funds earned and spent before opening a dedic...      1.000000
# 9   [I called the IRS (click here for IRS contact ...      1.000000
# 10  ["What exactly would the financial institution...      0.833333
# 11  ["The primary advantage is protection of your ...      0.800000
# 12  [Call Wells Fargo or go to a branch.  Tell the...      0.666667
# 13  [Yes.  For $15 it's not worth anyone's time to...      1.000000
# 14  [If you were looking to maximize your ability ...      0.800000
# 15  ["The best answer here is ""maybe, but probabl...      1.000000
# 16  [0% bonds are desirable for some individuals. ...      0.857143
# 17  ["There are many different kinds of SEC filing...      1.000000
# 18  [A bank can reject a loan if they feel you do ...      1.000000
# 19  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...      0.800000
#
#     answer_relevancy
# 0           0.830856
# 1           0.782628
# 2           0.829392
# 3           0.779775
# 4           0.840258
# 5           0.861889
# 6           0.877170
# 7           0.846074
# 8           0.912940
# 9           0.822008
# 10          0.834307
# 11          0.875194
# 12          0.836011
# 13          0.860272
# 14          0.847204
# 15          0.852136
# 16          0.896455
# 17          0.854352
# 18          0.821665
# 19          0.826029

# %%
result_all = pruned_ds.map(
    lambda record, idx: {
        "faithfulness (gpt-3.5-turbo-instruct)": df["faithfulness"][idx], 
        "answer_relevancy (gpt-3.5-turbo-instruct)": df["answer_relevancy"][idx], 
        "ragas_score (gpt-3.5-turbo-instruct)": 2 * df["faithfulness"][idx] * df["answer_relevancy"][idx] / (df["faithfulness"][idx] + df["answer_relevancy"][idx])
    },
    batched=False,
    with_indices=True,
    remove_columns=dataset.column_names
)
result_all
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Dataset({
#     features: ['EM', 'F1', 'faithfulness (gpt-3.5-turbo-instruct)', 'answer_relevancy (gpt-3.5-turbo-instruct)', 'ragas_score (gpt-3.5-turbo-instruct)'],
#     num_rows: 20
# })

# %%
result_all.to_pandas()
# Out:
#     EM   F1  faithfulness (gpt-3.5-turbo-instruct)  \
# 0    1  1.0                               1.000000
# 1    1  1.0                               1.000000
# 2    1  1.0                               1.000000
# 3    1  1.0                               1.000000
# 4    1  1.0                               1.000000
# 5    1  1.0                               1.000000
# 6    1  1.0                               0.833333
# 7    1  1.0                               1.000000
# 8    1  1.0                               1.000000
# 9    1  1.0                               1.000000
# 10   1  1.0                               0.833333
# 11   1  1.0                               0.800000
# 12   1  1.0                               0.666667
# 13   1  1.0                               1.000000
# 14   1  1.0                               0.800000
# 15   1  1.0                               1.000000
# 16   1  1.0                               0.857143
# 17   1  1.0                               1.000000
# 18   1  1.0                               1.000000
# 19   1  1.0                               0.800000
#
#     answer_relevancy (gpt-3.5-turbo-instruct)  \
# 0                                    0.830856
# 1                                    0.782628
# 2                                    0.829392
# 3                                    0.779775
# 4                                    0.840258
# 5                                    0.861889
# 6                                    0.877170
# 7                                    0.846074
# 8                                    0.912940
# 9                                    0.822008
# 10                                   0.834307
# 11                                   0.875194
# 12                                   0.836011
# 13                                   0.860272
# 14                                   0.847204
# 15                                   0.852136
# 16                                   0.896455
# 17                                   0.854352
# 18                                   0.821665
# 19                                   0.826029
#
#     ragas_score (gpt-3.5-turbo-instruct)
# 0                               0.907615
# 1                               0.878061
# 2                               0.906741
# 3                               0.876262
# 4                               0.913196
# 5                               0.925822
# 6                               0.854690
# 7                               0.916620
# 8                               0.954489
# 9                               0.902310
# 10                              0.833820
# 11                              0.835910
# 12                              0.741797
# 13                              0.924888
# 14                              0.822926
# 15                              0.920166
# 16                              0.876358
# 17                              0.921456
# 18                              0.902104
# 19                              0.812806

# %%
from langchain.chat_models import ChatOpenAI
from ragas.metrics import Faithfulness, AnswerRelevancy

gpt3 = ChatOpenAI(model_name="gpt-3.5-turbo")
faithfulness_gpt3 = Faithfulness(name="faithfulness", llm=gpt3)
answer_relevancy_gpt3 = AnswerRelevancy(name="answer_relevancy", llm=gpt3)

gpt4 = ChatOpenAI(model_name="gpt-4")
faithfulness_gpt4 = Faithfulness(name="faithfulness", llm=gpt4)
answer_relevancy_gpt4 = AnswerRelevancy(name="answer_relevancy", llm=gpt4)

# %%
# %%time
# evaluate

result_gpt3 = evaluate(
    pruned_ds,
    metrics=[
        faithfulness_gpt3,
        answer_relevancy_gpt3,
    ],
)

result_gpt3
# Out:
# evaluating with [faithfulness]
# 100%|██████████| 2/2 [06:16<00:00, 188.28s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [01:01<00:00, 30.58s/it]
# CPU times: user 599 ms, sys: 132 ms, total: 730 ms
# Wall time: 7min 18s
# {'ragas_score': 0.8163, 'faithfulness': 0.7840, 'answer_relevancy': 0.8513}

# %%
df = result_gpt3.to_pandas()
df
# Out:
#                                              question  \
# 0   Can I send a money order from USPS as a business?
# 1   1 EIN doing business under multiple business n...
# 2          Applying for and receiving business credit
# 3   Intentions of Deductible Amount for Small Busi...
# 4   Filing personal with 1099s versus business s-c...
# 5   Using credit card points to pay for tax deduct...
# 6   Investing/business with other people's money: ...
# 7   What approaches are there for pricing a small ...
# 8   How to account for money earned and spent prio...
# 9   Do I need a new EIN since I am hiring employee...
# 10  financial institution wants share member break...
# 11                        Sole proprietorship or LLC?
# 12  Where to request ACH Direct DEBIT of funds fro...
# 13  Challenged an apparently bogus credit card cha...
# 14  Employer options when setting up 401k for empl...
# 15          Following an investment guru a good idea?
# 16          Is there a reason to buy a 0% yield bond?
# 17  Should a retail trader bother about reading SE...
# 18  Will one’s education loan application be rejec...
# 19  Is there a dollar amount that, when adding Mas...
#
#                                              contexts  \
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   [Set up a meeting with the bank that handles y...
# 3   ["Short answer, yes. But this is not done thro...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [You don't need to notify the IRS of new membe...
# 10  ["What exactly would the financial institution...
# 11  [There is some benefit to creating a corporati...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [If you tell the collector that the claim isn'...
# 14  [Pre-Enron many companies forced the 401K matc...
# 15  [I think following the professional money mana...
# 16  [No, there isn't. There are a number of reason...
# 17  ["There are many different kinds of SEC filing...
# 18  [Edit: lazy math The answer to this question d...
# 19  [Yes, it's a simple calculation. (x+0.0625x)=2...
#
#                                                answer  \
# 0   Sure you can.  You can fill in whatever you wa...
# 1   You're confusing a lot of things here. Company...
# 2   "I'm afraid the great myth of limited liabilit...
# 3   "If your sole proprietorship losses exceed all...
# 4   Depends whom the 1099 was issued to. If it was...
# 5   "For simplicity, let's start by just consideri...
# 6   "Basically, you either borrow money, or get ot...
# 7   I don't have any experience in this, but this ...
# 8   Funds earned and spent before opening a dedica...
# 9   I called the IRS (click here for IRS contact i...
# 10  "What exactly would the financial institution ...
# 11  "The primary advantage is protection of your p...
# 12  Call Wells Fargo or go to a branch.  Tell them...
# 13  Yes.  For $15 it's not worth anyone's time to ...
# 14  If you were looking to maximize your ability t...
# 15  "The best answer here is ""maybe, but probably...
# 16  0% bonds are desirable for some individuals. I...
# 17  "There are many different kinds of SEC filings...
# 18  A bank can reject a loan if they feel you do n...
# 19  No. $188.23 has $11.76 tax = $199.99 $188.24 h...
#
#                                         ground_truths  faithfulness  \
# 0   [Sure you can.  You can fill in whatever you w...      1.000000
# 1   [You're confusing a lot of things here. Compan...      0.600000
# 2   ["I'm afraid the great myth of limited liabili...      1.000000
# 3   ["If your sole proprietorship losses exceed al...      0.500000
# 4   [Depends whom the 1099 was issued to. If it wa...      1.000000
# 5   ["For simplicity, let's start by just consider...      0.714286
# 6   ["Basically, you either borrow money, or get o...      1.000000
# 7   [I don't have any experience in this, but this...      1.000000
# 8   [Funds earned and spent before opening a dedic...      1.000000
# 9   [I called the IRS (click here for IRS contact ...      1.000000
# 10  ["What exactly would the financial institution...      1.000000
# 11  ["The primary advantage is protection of your ...      0.200000
# 12  [Call Wells Fargo or go to a branch.  Tell the...      0.000000
# 13  [Yes.  For $15 it's not worth anyone's time to...      1.000000
# 14  [If you were looking to maximize your ability ...      0.000000
# 15  ["The best answer here is ""maybe, but probabl...      1.000000
# 16  [0% bonds are desirable for some individuals. ...      0.666667
# 17  ["There are many different kinds of SEC filing...      1.000000
# 18  [A bank can reject a loan if they feel you do ...      1.000000
# 19  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...      1.000000
#
#     answer_relevancy
# 0           0.840292
# 1           0.776698
# 2           0.813242
# 3           0.788614
# 4           0.838918
# 5           0.859645
# 6           0.876517
# 7           0.857932
# 8           0.912479
# 9           0.898253
# 10          0.852350
# 11          0.871567
# 12          0.854941
# 13          0.884226
# 14          0.848235
# 15          0.869558
# 16          0.909031
# 17          0.822435
# 18          0.825780
# 19          0.825319

# %%
result_all = result_all.map(
    lambda record, idx: {
        "faithfulness (gpt-3.5-turbo)": df["faithfulness"][idx], 
        "answer_relevancy (gpt-3.5-turbo)": df["answer_relevancy"][idx], 
        "ragas_score (gpt-3.5-turbo)": 2 * df["faithfulness"][idx] * df["answer_relevancy"][idx] / (df["faithfulness"][idx] + df["answer_relevancy"][idx])
    },
    batched=False,
    with_indices=True
)
result_all
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Dataset({
#     features: ['EM', 'F1', 'faithfulness (gpt-3.5-turbo-instruct)', 'answer_relevancy (gpt-3.5-turbo-instruct)', 'ragas_score (gpt-3.5-turbo-instruct)', 'faithfulness (gpt-3.5-turbo)', 'answer_relevancy (gpt-3.5-turbo)', 'ragas_score (gpt-3.5-turbo)'],
#     num_rows: 20
# })

# %%
result_all.to_pandas()
# Out:
#     EM   F1  faithfulness (gpt-3.5-turbo-instruct)  \
# 0    1  1.0                               1.000000
# 1    1  1.0                               1.000000
# 2    1  1.0                               1.000000
# 3    1  1.0                               1.000000
# 4    1  1.0                               1.000000
# 5    1  1.0                               1.000000
# 6    1  1.0                               0.833333
# 7    1  1.0                               1.000000
# 8    1  1.0                               1.000000
# 9    1  1.0                               1.000000
# 10   1  1.0                               0.833333
# 11   1  1.0                               0.800000
# 12   1  1.0                               0.666667
# 13   1  1.0                               1.000000
# 14   1  1.0                               0.800000
# 15   1  1.0                               1.000000
# 16   1  1.0                               0.857143
# 17   1  1.0                               1.000000
# 18   1  1.0                               1.000000
# 19   1  1.0                               0.800000
#
#     answer_relevancy (gpt-3.5-turbo-instruct)  \
# 0                                    0.830856
# 1                                    0.782628
# 2                                    0.829392
# 3                                    0.779775
# 4                                    0.840258
# 5                                    0.861889
# 6                                    0.877170
# 7                                    0.846074
# 8                                    0.912940
# 9                                    0.822008
# 10                                   0.834307
# 11                                   0.875194
# 12                                   0.836011
# 13                                   0.860272
# 14                                   0.847204
# 15                                   0.852136
# 16                                   0.896455
# 17                                   0.854352
# 18                                   0.821665
# 19                                   0.826029
#
#     ragas_score (gpt-3.5-turbo-instruct)  faithfulness (gpt-3.5-turbo)  \
# 0                               0.907615                      1.000000
# 1                               0.878061                      0.600000
# 2                               0.906741                      1.000000
# 3                               0.876262                      0.500000
# 4                               0.913196                      1.000000
# 5                               0.925822                      0.714286
# 6                               0.854690                      1.000000
# 7                               0.916620                      1.000000
# 8                               0.954489                      1.000000
# 9                               0.902310                      1.000000
# 10                              0.833820                      1.000000
# 11                              0.835910                      0.200000
# 12                              0.741797                      0.000000
# 13                              0.924888                      1.000000
# 14                              0.822926                      0.000000
# 15                              0.920166                      1.000000
# 16                              0.876358                      0.666667
# 17                              0.921456                      1.000000
# 18                              0.902104                      1.000000
# 19                              0.812806                      1.000000
#
#     answer_relevancy (gpt-3.5-turbo)  ragas_score (gpt-3.5-turbo)
# 0                           0.840292                     0.913216
# 1                           0.776698                     0.677010
# 2                           0.813242                     0.897003
# 3                           0.788614                     0.611986
# 4                           0.838918                     0.912404
# 5                           0.859645                     0.780253
# 6                           0.876517                     0.934196
# 7                           0.857932                     0.923534
# 8                           0.912479                     0.954237
# 9                           0.898253                     0.946400
# 10                          0.852350                     0.920290
# 11                          0.871567                     0.325343
# 12                          0.854941                     0.000000
# 13                          0.884226                     0.938556
# 14                          0.848235                     0.000000
# 15                          0.869558                     0.930229
# 16                          0.909031                     0.769209
# 17                          0.822435                     0.902567
# 18                          0.825780                     0.904578
# 19                          0.825319                     0.904301

# %%
# %%time
# evaluate

result_gpt4 = evaluate(
    pruned_ds,
    metrics=[
        faithfulness_gpt4,
        answer_relevancy_gpt4,
    ],
)

result_gpt4
# Out:
# evaluating with [faithfulness]
#   0%|          | 0/2 [00:00<?, ?it/s]Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).
# 100%|██████████| 2/2 [25:47<00:00, 773.91s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [01:09<00:00, 34.88s/it]
# CPU times: user 670 ms, sys: 428 ms, total: 1.1 s
# Wall time: 26min 58s
# {'ragas_score': 0.8200, 'faithfulness': 0.7850, 'answer_relevancy': 0.8583}

# %%
df = result_gpt4.to_pandas()
df
# Out:
#                                              question  \
# 0   Can I send a money order from USPS as a business?
# 1   1 EIN doing business under multiple business n...
# 2          Applying for and receiving business credit
# 3   Intentions of Deductible Amount for Small Busi...
# 4   Filing personal with 1099s versus business s-c...
# 5   Using credit card points to pay for tax deduct...
# 6   Investing/business with other people's money: ...
# 7   What approaches are there for pricing a small ...
# 8   How to account for money earned and spent prio...
# 9   Do I need a new EIN since I am hiring employee...
# 10  financial institution wants share member break...
# 11                        Sole proprietorship or LLC?
# 12  Where to request ACH Direct DEBIT of funds fro...
# 13  Challenged an apparently bogus credit card cha...
# 14  Employer options when setting up 401k for empl...
# 15          Following an investment guru a good idea?
# 16          Is there a reason to buy a 0% yield bond?
# 17  Should a retail trader bother about reading SE...
# 18  Will one’s education loan application be rejec...
# 19  Is there a dollar amount that, when adding Mas...
#
#                                              contexts  \
# 0   [Sure you can.  You can fill in whatever you w...
# 1   [You're confusing a lot of things here. Compan...
# 2   [Set up a meeting with the bank that handles y...
# 3   ["Short answer, yes. But this is not done thro...
# 4   [Depends whom the 1099 was issued to. If it wa...
# 5   ["For simplicity, let's start by just consider...
# 6   ["Basically, you either borrow money, or get o...
# 7   [I don't have any experience in this, but this...
# 8   [Funds earned and spent before opening a dedic...
# 9   [You don't need to notify the IRS of new membe...
# 10  ["What exactly would the financial institution...
# 11  [There is some benefit to creating a corporati...
# 12  [Call Wells Fargo or go to a branch.  Tell the...
# 13  [If you tell the collector that the claim isn'...
# 14  [Pre-Enron many companies forced the 401K matc...
# 15  [I think following the professional money mana...
# 16  [No, there isn't. There are a number of reason...
# 17  ["There are many different kinds of SEC filing...
# 18  [Edit: lazy math The answer to this question d...
# 19  [Yes, it's a simple calculation. (x+0.0625x)=2...
#
#                                                answer  \
# 0   Sure you can.  You can fill in whatever you wa...
# 1   You're confusing a lot of things here. Company...
# 2   "I'm afraid the great myth of limited liabilit...
# 3   "If your sole proprietorship losses exceed all...
# 4   Depends whom the 1099 was issued to. If it was...
# 5   "For simplicity, let's start by just consideri...
# 6   "Basically, you either borrow money, or get ot...
# 7   I don't have any experience in this, but this ...
# 8   Funds earned and spent before opening a dedica...
# 9   I called the IRS (click here for IRS contact i...
# 10  "What exactly would the financial institution ...
# 11  "The primary advantage is protection of your p...
# 12  Call Wells Fargo or go to a branch.  Tell them...
# 13  Yes.  For $15 it's not worth anyone's time to ...
# 14  If you were looking to maximize your ability t...
# 15  "The best answer here is ""maybe, but probably...
# 16  0% bonds are desirable for some individuals. I...
# 17  "There are many different kinds of SEC filings...
# 18  A bank can reject a loan if they feel you do n...
# 19  No. $188.23 has $11.76 tax = $199.99 $188.24 h...
#
#                                         ground_truths  faithfulness  \
# 0   [Sure you can.  You can fill in whatever you w...      0.857143
# 1   [You're confusing a lot of things here. Compan...      0.909091
# 2   ["I'm afraid the great myth of limited liabili...      1.000000
# 3   ["If your sole proprietorship losses exceed al...      0.000000
# 4   [Depends whom the 1099 was issued to. If it wa...      1.000000
# 5   ["For simplicity, let's start by just consider...      1.000000
# 6   ["Basically, you either borrow money, or get o...      0.400000
# 7   [I don't have any experience in this, but this...      1.000000
# 8   [Funds earned and spent before opening a dedic...      1.000000
# 9   [I called the IRS (click here for IRS contact ...      0.666667
# 10  ["What exactly would the financial institution...      1.000000
# 11  ["The primary advantage is protection of your ...      0.066667
# 12  [Call Wells Fargo or go to a branch.  Tell the...      0.800000
# 13  [Yes.  For $15 it's not worth anyone's time to...      1.000000
# 14  [If you were looking to maximize your ability ...      0.000000
# 15  ["The best answer here is ""maybe, but probabl...      1.000000
# 16  [0% bonds are desirable for some individuals. ...      1.000000
# 17  ["There are many different kinds of SEC filing...      1.000000
# 18  [A bank can reject a loan if they feel you do ...      1.000000
# 19  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...      1.000000
#
#     answer_relevancy
# 0           0.879709
# 1           0.775887
# 2           0.845730
# 3           0.777950
# 4           0.878502
# 5           0.876391
# 6           0.870155
# 7           0.847384
# 8           0.919039
# 9           0.846412
# 10          0.865757
# 11          0.883126
# 12          0.832728
# 13          0.866034
# 14          0.845157
# 15          0.868222
# 16          0.907458
# 17          0.869455
# 18          0.832354
# 19          0.879010

# %%
result_all = result_all.map(
    lambda record, idx: {
        "faithfulness (gpt-4)": df["faithfulness"][idx], 
        "answer_relevancy (gpt-4)": df["answer_relevancy"][idx], 
        "ragas_score (gpt-4)": 2 * df["faithfulness"][idx] * df["answer_relevancy"][idx] / (df["faithfulness"][idx] + df["answer_relevancy"][idx])
    },
    batched=False,
    with_indices=True
)
result_all
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Dataset({
#     features: ['EM', 'F1', 'faithfulness (gpt-3.5-turbo-instruct)', 'answer_relevancy (gpt-3.5-turbo-instruct)', 'ragas_score (gpt-3.5-turbo-instruct)', 'faithfulness (gpt-3.5-turbo)', 'answer_relevancy (gpt-3.5-turbo)', 'ragas_score (gpt-3.5-turbo)', 'faithfulness (gpt-4)', 'answer_relevancy (gpt-4)', 'ragas_score (gpt-4)'],
#     num_rows: 20
# })

# %%
result_all.to_pandas()
# Out:
#     EM   F1  faithfulness (gpt-3.5-turbo-instruct)  \
# 0    1  1.0                               1.000000
# 1    1  1.0                               1.000000
# 2    1  1.0                               1.000000
# 3    1  1.0                               1.000000
# 4    1  1.0                               1.000000
# 5    1  1.0                               1.000000
# 6    1  1.0                               0.833333
# 7    1  1.0                               1.000000
# 8    1  1.0                               1.000000
# 9    1  1.0                               1.000000
# 10   1  1.0                               0.833333
# 11   1  1.0                               0.800000
# 12   1  1.0                               0.666667
# 13   1  1.0                               1.000000
# 14   1  1.0                               0.800000
# 15   1  1.0                               1.000000
# 16   1  1.0                               0.857143
# 17   1  1.0                               1.000000
# 18   1  1.0                               1.000000
# 19   1  1.0                               0.800000
#
#     answer_relevancy (gpt-3.5-turbo-instruct)  \
# 0                                    0.830856
# 1                                    0.782628
# 2                                    0.829392
# 3                                    0.779775
# 4                                    0.840258
# 5                                    0.861889
# 6                                    0.877170
# 7                                    0.846074
# 8                                    0.912940
# 9                                    0.822008
# 10                                   0.834307
# 11                                   0.875194
# 12                                   0.836011
# 13                                   0.860272
# 14                                   0.847204
# 15                                   0.852136
# 16                                   0.896455
# 17                                   0.854352
# 18                                   0.821665
# 19                                   0.826029
#
#     ragas_score (gpt-3.5-turbo-instruct)  faithfulness (gpt-3.5-turbo)  \
# 0                               0.907615                      1.000000
# 1                               0.878061                      0.600000
# 2                               0.906741                      1.000000
# 3                               0.876262                      0.500000
# 4                               0.913196                      1.000000
# 5                               0.925822                      0.714286
# 6                               0.854690                      1.000000
# 7                               0.916620                      1.000000
# 8                               0.954489                      1.000000
# 9                               0.902310                      1.000000
# 10                              0.833820                      1.000000
# 11                              0.835910                      0.200000
# 12                              0.741797                      0.000000
# 13                              0.924888                      1.000000
# 14                              0.822926                      0.000000
# 15                              0.920166                      1.000000
# 16                              0.876358                      0.666667
# 17                              0.921456                      1.000000
# 18                              0.902104                      1.000000
# 19                              0.812806                      1.000000
#
#     answer_relevancy (gpt-3.5-turbo)  ragas_score (gpt-3.5-turbo)  \
# 0                           0.840292                     0.913216
# 1                           0.776698                     0.677010
# 2                           0.813242                     0.897003
# 3                           0.788614                     0.611986
# 4                           0.838918                     0.912404
# 5                           0.859645                     0.780253
# 6                           0.876517                     0.934196
# 7                           0.857932                     0.923534
# 8                           0.912479                     0.954237
# 9                           0.898253                     0.946400
# 10                          0.852350                     0.920290
# 11                          0.871567                     0.325343
# 12                          0.854941                     0.000000
# 13                          0.884226                     0.938556
# 14                          0.848235                     0.000000
# 15                          0.869558                     0.930229
# 16                          0.909031                     0.769209
# 17                          0.822435                     0.902567
# 18                          0.825780                     0.904578
# 19                          0.825319                     0.904301
#
#     faithfulness (gpt-4)  answer_relevancy (gpt-4)  ragas_score (gpt-4)
# 0               0.857143                  0.879709             0.868279
# 1               0.909091                  0.775887             0.837224
# 2               1.000000                  0.845730             0.916418
# 3               0.000000                  0.777950             0.000000
# 4               1.000000                  0.878502             0.935322
# 5               1.000000                  0.876391             0.934124
# 6               0.400000                  0.870155             0.548062
# 7               1.000000                  0.847384             0.917388
# 8               1.000000                  0.919039             0.957812
# 9               0.666667                  0.846412             0.745863
# 10              1.000000                  0.865757             0.928049
# 11              0.066667                  0.883126             0.123975
# 12              0.800000                  0.832728             0.816036
# 13              1.000000                  0.866034             0.928208
# 14              0.000000                  0.845157             0.000000
# 15              1.000000                  0.868222             0.929463
# 16              1.000000                  0.907458             0.951484
# 17              1.000000                  0.869455             0.930170
# 18              1.000000                  0.832354             0.908508
# 19              1.000000                  0.879010             0.935609

# %%
pruned_ds.to_csv("pruned-ds.csv", sep='\t')
result_all.to_csv("pruned-result.csv", sep='\t')
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 3009
