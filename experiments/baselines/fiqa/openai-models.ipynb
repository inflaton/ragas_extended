# %% [markdown]
# # Bring your own LLMs
#
# Ragas uses langchain under the hood for connecting to LLMs for metrices that require them. This means you can swap out the default LLM we use (`gpt-3.5-turbo-16k`) to use any 100s of API supported out of the box with langchain.
#
# - [Completion LLMs Supported](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.llms)
# - [Chat based LLMs Supported](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.chat_models)
#
# This guide will show you how to use another or LLM API for evaluation.

# %% [markdown]
# ## Evaluating with GPT4
#
# Ragas uses gpt3.5 by default but using gpt4 for evaluation can improve the results so lets use that for the `Faithfulness` metric
#
# To start-off, we initialise the gpt4 `chat_model` from langchain

# %%
# %pip show ragas
# Out:
# Name: ragas
# Version: 0.0.15.dev2+gd590b10.d20230924
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /Users/inflaton/miniconda3/lib/python3.10/site-packages
# Requires: datasets, langchain, numpy, openai, pydantic, pysbd, sentence-transformers, transformers
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["RAGAS_OPENAI_MODEL_NAME"] = 'gpt-3.5-turbo'
# Out:
# True

# %% [markdown]
# Now initialise `Faithfulness` with `gpt-3.5-turbo-instruct` and `gpt4`

# %%
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from ragas.metrics import Faithfulness, AnswerRelevancy

gpt_instruct = OpenAI(model_name="gpt-3.5-turbo-instruct")
faithfulness_instruct = Faithfulness(name="faithfulness", llm=gpt_instruct)
answer_relevancy_instruct = AnswerRelevancy(name="answer_relevancy", llm=gpt_instruct)

gpt4 = ChatOpenAI(model_name="gpt-4")
faithfulness_gpt4 = Faithfulness(name="faithfulness", llm=gpt4)
answer_relevancy_gpt4 = AnswerRelevancy(name="answer_relevancy", llm=gpt4)

# %% [markdown]
# That's it!
#
# Now lets run the evaluations using the example from [quickstart](../quickstart.ipnb).

# %%
# data
from datasets import load_dataset

fiqa_eval = load_dataset("explodinggradients/fiqa", "ragas_eval")
fiqa_eval
# Out:
# DatasetDict({
#     baseline: Dataset({
#         features: ['question', 'ground_truths', 'answer', 'contexts'],
#         num_rows: 30
#     })
# })

# %%
"""
Official evaluation script for QAConv, modified from SQuAD 2.0.

 * Copyright (c) 2021, salesforce.com, inc.
 * All rights reserved.
 * SPDX-License-Identifier: BSD-3-Clause
 * For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

"""

import collections
import re
import string


def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def get_tokens(s):
    if not s:
        return []
    return normalize_answer(s).split()


def compute_exact(a_gold, a_pred):
    return int(normalize_answer(a_gold) == normalize_answer(a_pred))


def compute_f1(a_gold, a_pred):
    gold_toks = get_tokens(a_gold)
    pred_toks = get_tokens(a_pred)
    common = collections.Counter(gold_toks) & collections.Counter(pred_toks)
    num_same = sum(common.values())
    if len(gold_toks) == 0 or len(pred_toks) == 0:
        # If either is no-answer, then F1 is 1 if they agree, 0 otherwise
        return int(gold_toks == pred_toks)
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(pred_toks)
    recall = 1.0 * num_same / len(gold_toks)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1

# %%
dataset = fiqa_eval["baseline"]
new_ds = dataset.map(
    lambda record, idx: {
        "answer": record["ground_truths"][0] if idx < 5 else  record["answer"],
        "EM": compute_exact(record['ground_truths'][0], record["ground_truths"][0] if idx < 5 else  record["answer"]), 
        "F1": compute_f1(record['ground_truths'][0], record["ground_truths"][0] if idx < 5 else  record["answer"])
    },
    batched=False,
    with_indices=True,
)
new_ds
# Out:
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'ground_truths', 'answer', 'contexts', 'EM', 'F1'],
#     num_rows: 30
# })

# %%
new_ds.to_pandas()
# Out:
#                                              question  \
# 0   How to deposit a cheque issued to an associate...
# 1   Can I send a money order from USPS as a business?
# 2   1 EIN doing business under multiple business n...
# 3          Applying for and receiving business credit
# 4                401k Transfer After Business Closure
# 5   What are the ins/outs of writing equipment pur...
# 6   Can a entrepreneur hire a self-employed busine...
# 7   Intentions of Deductible Amount for Small Busi...
# 8   How can I deposit a check made out to my busin...
# 9   Filing personal with 1099s versus business s-c...
# 10  Using credit card points to pay for tax deduct...
# 11  How can I make $250,000.00 from trading/invest...
# 12  Investing/business with other people's money: ...
# 13  What approaches are there for pricing a small ...
# 14  How to account for money earned and spent prio...
# 15  Do I need a new EIN since I am hiring employee...
# 16       Privacy preferences on creditworthiness data
# 17            Have plenty of cash flow but bad credit
# 18  financial institution wants share member break...
# 19                        Sole proprietorship or LLC?
# 20  What percentage of my company should I have if...
# 21  Where to request ACH Direct DEBIT of funds fro...
# 22  Challenged an apparently bogus credit card cha...
# 23  Employer options when setting up 401k for empl...
# 24          Following an investment guru a good idea?
# 25          Is there a reason to buy a 0% yield bond?
# 26  Should a retail trader bother about reading SE...
# 27  Will one’s education loan application be rejec...
# 28  Is there a dollar amount that, when adding Mas...
# 29  Is it wise to have plenty of current accounts ...
#
#                                         ground_truths  \
# 0   [Have the check reissued to the proper payee.J...
# 1   [Sure you can.  You can fill in whatever you w...
# 2   [You're confusing a lot of things here. Compan...
# 3   ["I'm afraid the great myth of limited liabili...
# 4   [You should probably consult an attorney. Howe...
# 5   [Most items used in business have to be deprec...
# 6   [Yes. I can by all means start my own company ...
# 7   ["If your sole proprietorship losses exceed al...
# 8   [You should have a separate business account. ...
# 9   [Depends whom the 1099 was issued to. If it wa...
# 10  ["For simplicity, let's start by just consider...
# 11  [Deposit $3,500 each month in a brokerage acco...
# 12  ["Basically, you either borrow money, or get o...
# 13  [I don't have any experience in this, but this...
# 14  [Funds earned and spent before opening a dedic...
# 15  [I called the IRS (click here for IRS contact ...
# 16  [See the first item in the list: For our every...
# 17  [Set up a meeting with the bank that handles y...
# 18  ["What exactly would the financial institution...
# 19  ["The primary advantage is protection of your ...
# 20  [There is no universal answer here; it depends...
# 21  [Call Wells Fargo or go to a branch.  Tell the...
# 22  [Yes.  For $15 it's not worth anyone's time to...
# 23  [If you were looking to maximize your ability ...
# 24  ["The best answer here is ""maybe, but probabl...
# 25  [0% bonds are desirable for some individuals. ...
# 26  ["There are many different kinds of SEC filing...
# 27  [A bank can reject a loan if they feel you do ...
# 28  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...
# 29  [Its actually a good thing.  The #1 factor to ...
#
#                                                answer  \
# 0   Have the check reissued to the proper payee.Ju...
# 1   Sure you can.  You can fill in whatever you wa...
# 2   You're confusing a lot of things here. Company...
# 3   "I'm afraid the great myth of limited liabilit...
# 4   You should probably consult an attorney. Howev...
# 5   \nWriting equipment purchases off as business ...
# 6   \nYes, an entrepreneur can hire a self-employe...
# 7   \nThe intention of deductible amounts for smal...
# 8   \nYou can deposit a check made out to your bus...
# 9   \nFiling personal taxes with 1099s versus fili...
# 10  \nUsing credit card points to pay for tax dedu...
# 11  \nMaking $250,000.00 from trading/investing/bu...
# 12  \nInvesting/business with other people's money...
# 13  \nThere are several approaches for pricing a s...
# 14  \nMoney earned and spent prior to establishing...
# 15  \nNo, you do not need a new EIN since you are ...
# 16  \nThe best answer to this question is that you...
# 17  \nIf you have plenty of cash flow but bad cred...
# 18  \nThe financial institution would need to see ...
# 19  \nIt depends on your individual situation and ...
# 20  \nIt is generally recommended to have no more ...
# 21  \nThe best place to request ACH Direct DEBIT o...
# 22  \nNow, the collector is obliged to go back to ...
# 23  \nWhen setting up a 401k plan for employees, e...
# 24  \nNo, following an investment guru is not nece...
# 25  \nYes, there is a reason to buy a 0% yield bon...
# 26  \nIt depends on the individual investor's goal...
# 27  \nIt is possible that one's education loan app...
# 28  \nNo, there is not a dollar amount that, when ...
# 29  \nYes, it is wise to have plenty of current ac...
#
#                                              contexts  EM        F1
# 0   [Just have the associate sign the back and the...   1  1.000000
# 1   [Sure you can.  You can fill in whatever you w...   1  1.000000
# 2   [You're confusing a lot of things here. Compan...   1  1.000000
# 3   [Set up a meeting with the bank that handles y...   1  1.000000
# 4   [The time horizon for your 401K/IRA is essenti...   1  1.000000
# 5   [You would report it as business income on Sch...   0  0.424742
# 6   [Yes. I can by all means start my own company ...   0  0.226087
# 7   ["Short answer, yes. But this is not done thro...   0  0.161850
# 8   ["I have checked with Bank of America, and the...   0  0.186528
# 9   [Depends whom the 1099 was issued to. If it wa...   0  0.214286
# 10  ["For simplicity, let's start by just consider...   0  0.199367
# 11  ["The answer to your question is Forex trading...   0  0.202381
# 12  ["Basically, you either borrow money, or get o...   0  0.356436
# 13  [I don't have any experience in this, but this...   0  0.383495
# 14  [Funds earned and spent before opening a dedic...   0  0.671642
# 15  [You don't need to notify the IRS of new membe...   0  0.331288
# 16  [See the first item in the list: For our every...   0  0.419753
# 17  [This is probably a good time to note that cre...   0  0.110687
# 18  ["What exactly would the financial institution...   0  0.596273
# 19  [There is some benefit to creating a corporati...   0  0.267606
# 20  [To me it depends on things like your net wort...   0  0.175258
# 21  [Call Wells Fargo or go to a branch.  Tell the...   0  0.353982
# 22  [If you tell the collector that the claim isn'...   0  0.423913
# 23  [Pre-Enron many companies forced the 401K matc...   0  0.219780
# 24  [I think following the professional money mana...   0  0.443114
# 25  [No, there isn't. There are a number of reason...   0  0.276596
# 26  ["There are many different kinds of SEC filing...   0  0.214000
# 27  [Edit: lazy math The answer to this question d...   0  0.225352
# 28  [Yes, it's a simple calculation. (x+0.0625x)=2...   0  0.054054
# 29  [I don't think there's any law against having ...   0  0.185907

# %%
# %%time
# evaluate
from ragas import evaluate
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
)

result = evaluate(
    new_ds,
    metrics=[
        faithfulness,
        answer_relevancy,
    ],
)

result
# Out:
# evaluating with [faithfulness]
# 100%|██████████| 2/2 [05:44<00:00, 172.45s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [01:15<00:00, 37.98s/it]
# CPU times: user 391 ms, sys: 343 ms, total: 734 ms
# Wall time: 7min 1s
# {'ragas_score': 0.8333, 'faithfulness': 0.7698, 'answer_relevancy': 0.9083}

# %%
df = result.to_pandas()
df
# Out:
#                                              question  \
# 0   How to deposit a cheque issued to an associate...
# 1   Can I send a money order from USPS as a business?
# 2   1 EIN doing business under multiple business n...
# 3          Applying for and receiving business credit
# 4                401k Transfer After Business Closure
# 5   What are the ins/outs of writing equipment pur...
# 6   Can a entrepreneur hire a self-employed busine...
# 7   Intentions of Deductible Amount for Small Busi...
# 8   How can I deposit a check made out to my busin...
# 9   Filing personal with 1099s versus business s-c...
# 10  Using credit card points to pay for tax deduct...
# 11  How can I make $250,000.00 from trading/invest...
# 12  Investing/business with other people's money: ...
# 13  What approaches are there for pricing a small ...
# 14  How to account for money earned and spent prio...
# 15  Do I need a new EIN since I am hiring employee...
# 16       Privacy preferences on creditworthiness data
# 17            Have plenty of cash flow but bad credit
# 18  financial institution wants share member break...
# 19                        Sole proprietorship or LLC?
# 20  What percentage of my company should I have if...
# 21  Where to request ACH Direct DEBIT of funds fro...
# 22  Challenged an apparently bogus credit card cha...
# 23  Employer options when setting up 401k for empl...
# 24          Following an investment guru a good idea?
# 25          Is there a reason to buy a 0% yield bond?
# 26  Should a retail trader bother about reading SE...
# 27  Will one’s education loan application be rejec...
# 28  Is there a dollar amount that, when adding Mas...
# 29  Is it wise to have plenty of current accounts ...
#
#                                              contexts  \
# 0   [Just have the associate sign the back and the...
# 1   [Sure you can.  You can fill in whatever you w...
# 2   [You're confusing a lot of things here. Compan...
# 3   [Set up a meeting with the bank that handles y...
# 4   [The time horizon for your 401K/IRA is essenti...
# 5   [You would report it as business income on Sch...
# 6   [Yes. I can by all means start my own company ...
# 7   ["Short answer, yes. But this is not done thro...
# 8   ["I have checked with Bank of America, and the...
# 9   [Depends whom the 1099 was issued to. If it wa...
# 10  ["For simplicity, let's start by just consider...
# 11  ["The answer to your question is Forex trading...
# 12  ["Basically, you either borrow money, or get o...
# 13  [I don't have any experience in this, but this...
# 14  [Funds earned and spent before opening a dedic...
# 15  [You don't need to notify the IRS of new membe...
# 16  [See the first item in the list: For our every...
# 17  [This is probably a good time to note that cre...
# 18  ["What exactly would the financial institution...
# 19  [There is some benefit to creating a corporati...
# 20  [To me it depends on things like your net wort...
# 21  [Call Wells Fargo or go to a branch.  Tell the...
# 22  [If you tell the collector that the claim isn'...
# 23  [Pre-Enron many companies forced the 401K matc...
# 24  [I think following the professional money mana...
# 25  [No, there isn't. There are a number of reason...
# 26  ["There are many different kinds of SEC filing...
# 27  [Edit: lazy math The answer to this question d...
# 28  [Yes, it's a simple calculation. (x+0.0625x)=2...
# 29  [I don't think there's any law against having ...
#
#                                                answer  \
# 0   Have the check reissued to the proper payee.Ju...
# 1   Sure you can.  You can fill in whatever you wa...
# 2   You're confusing a lot of things here. Company...
# 3   "I'm afraid the great myth of limited liabilit...
# 4   You should probably consult an attorney. Howev...
# 5   \nWriting equipment purchases off as business ...
# 6   \nYes, an entrepreneur can hire a self-employe...
# 7   \nThe intention of deductible amounts for smal...
# 8   \nYou can deposit a check made out to your bus...
# 9   \nFiling personal taxes with 1099s versus fili...
# 10  \nUsing credit card points to pay for tax dedu...
# 11  \nMaking $250,000.00 from trading/investing/bu...
# 12  \nInvesting/business with other people's money...
# 13  \nThere are several approaches for pricing a s...
# 14  \nMoney earned and spent prior to establishing...
# 15  \nNo, you do not need a new EIN since you are ...
# 16  \nThe best answer to this question is that you...
# 17  \nIf you have plenty of cash flow but bad cred...
# 18  \nThe financial institution would need to see ...
# 19  \nIt depends on your individual situation and ...
# 20  \nIt is generally recommended to have no more ...
# 21  \nThe best place to request ACH Direct DEBIT o...
# 22  \nNow, the collector is obliged to go back to ...
# 23  \nWhen setting up a 401k plan for employees, e...
# 24  \nNo, following an investment guru is not nece...
# 25  \nYes, there is a reason to buy a 0% yield bon...
# 26  \nIt depends on the individual investor's goal...
# 27  \nIt is possible that one's education loan app...
# 28  \nNo, there is not a dollar amount that, when ...
# 29  \nYes, it is wise to have plenty of current ac...
#
#                                         ground_truths  faithfulness  \
# 0   [Have the check reissued to the proper payee.J...      0.666667
# 1   [Sure you can.  You can fill in whatever you w...      1.000000
# 2   [You're confusing a lot of things here. Compan...      0.857143
# 3   ["I'm afraid the great myth of limited liabili...      1.000000
# 4   [You should probably consult an attorney. Howe...      0.666667
# 5   [Most items used in business have to be deprec...      1.000000
# 6   [Yes. I can by all means start my own company ...      1.000000
# 7   ["If your sole proprietorship losses exceed al...      0.800000
# 8   [You should have a separate business account. ...      0.600000
# 9   [Depends whom the 1099 was issued to. If it wa...      0.500000
# 10  ["For simplicity, let's start by just consider...      1.000000
# 11  [Deposit $3,500 each month in a brokerage acco...      0.200000
# 12  ["Basically, you either borrow money, or get o...      1.000000
# 13  [I don't have any experience in this, but this...      1.000000
# 14  [Funds earned and spent before opening a dedic...      1.000000
# 15  [I called the IRS (click here for IRS contact ...      0.666667
# 16  [See the first item in the list: For our every...      1.000000
# 17  [Set up a meeting with the bank that handles y...      0.666667
# 18  ["What exactly would the financial institution...      1.000000
# 19  ["The primary advantage is protection of your ...      0.500000
# 20  [There is no universal answer here; it depends...      0.500000
# 21  [Call Wells Fargo or go to a branch.  Tell the...      0.666667
# 22  [Yes.  For $15 it's not worth anyone's time to...      0.800000
# 23  [If you were looking to maximize your ability ...      0.285714
# 24  ["The best answer here is ""maybe, but probabl...      1.000000
# 25  [0% bonds are desirable for some individuals. ...      0.800000
# 26  ["There are many different kinds of SEC filing...      1.000000
# 27  [A bank can reject a loan if they feel you do ...      0.666667
# 28  [No. $188.23 has $11.76 tax = $199.99 $188.24 ...      1.000000
# 29  [Its actually a good thing.  The #1 factor to ...      0.250000
#
#     answer_relevancy
# 0           0.821788
# 1           0.844772
# 2           0.777502
# 3           0.813215
# 4           0.769605
# 5           0.949131
# 6           0.916488
# 7           0.904527
# 8           0.976848
# 9           0.962691
# 10          0.913416
# 11          0.954900
# 12          0.951978
# 13          0.977373
# 14          0.919864
# 15          0.994253
# 16          0.854985
# 17          0.894678
# 18          0.856767
# 19          0.934819
# 20          0.863841
# 21          0.964975
# 22          0.811748
# 23          0.962229
# 24          0.927224
# 25          0.974189
# 26          0.938227
# 27          0.876366
# 28          0.993498
# 29          0.946056

# %%
result2 = new_ds.map(
    lambda record, idx: {
        "faithfulness": df["faithfulness"][idx], 
        "answer_relevancy": df["answer_relevancy"][idx], 
        "ragas_score": df["faithfulness"][idx] * df["answer_relevancy"][idx] / (df["faithfulness"][idx] + df["answer_relevancy"][idx])
    },
    batched=False,
    with_indices=True,
    remove_columns=dataset.column_names
)
result2
# Out:
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Dataset({
#     features: ['EM', 'F1', 'faithfulness', 'answer_relevancy', 'ragas_score'],
#     num_rows: 30
# })

# %%
df2 = result2.to_pandas()
df2
# Out:
#     EM        F1  faithfulness  answer_relevancy  ragas_score
# 0    1  1.000000      0.666667          0.821788     0.368072
# 1    1  1.000000      1.000000          0.844772     0.457928
# 2    1  1.000000      0.857143          0.777502     0.407691
# 3    1  1.000000      1.000000          0.813215     0.448493
# 4    1  1.000000      0.666667          0.769605     0.357223
# 5    0  0.424742      1.000000          0.949131     0.486951
# 6    0  0.226087      1.000000          0.916488     0.478212
# 7    0  0.161850      0.800000          0.904527     0.424529
# 8    0  0.186528      0.600000          0.976848     0.371697
# 9    0  0.214286      0.500000          0.962691     0.329082
# 10   0  0.199367      1.000000          0.913416     0.477375
# 11   0  0.202381      0.200000          0.954900     0.165365
# 12   0  0.356436      1.000000          0.951978     0.487699
# 13   0  0.383495      1.000000          0.977373     0.494278
# 14   0  0.671642      1.000000          0.919864     0.479130
# 15   0  0.331288      0.666667          0.994253     0.399077
# 16   0  0.419753      1.000000          0.854985     0.460912
# 17   0  0.110687      0.666667          0.894678     0.382012
# 18   0  0.596273      1.000000          0.856767     0.461429
# 19   0  0.267606      0.500000          0.934819     0.325762
# 20   0  0.175258      0.500000          0.863841     0.316694
# 21   0  0.353982      0.666667          0.964975     0.394276
# 22   0  0.423913      0.800000          0.811748     0.402916
# 23   0  0.219780      0.285714          0.962229     0.220301
# 24   0  0.443114      1.000000          0.927224     0.481119
# 25   0  0.276596      0.800000          0.974189     0.439272
# 26   0  0.214000      1.000000          0.938227     0.484065
# 27   0  0.225352      0.666667          0.876366     0.378634
# 28   0  0.054054      1.000000          0.993498     0.498369
# 29   0  0.185907      0.250000          0.946056     0.197745

# %%
result2.to_csv("gpt-3.5-turbo.csv.log")
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 2023

# %%
# %%time
# evaluate

result_gpt4 = evaluate(
    new_ds,
    metrics=[
        faithfulness_gpt4,
        answer_relevancy_gpt4,
    ],
)

result_gpt4
# Out:
# evaluating with [faithfulness]
# 100%|██████████| 2/2 [17:08<00:00, 514.13s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [01:47<00:00, 53.54s/it]
# CPU times: user 806 ms, sys: 416 ms, total: 1.22 s
# Wall time: 18min 56s
# {'ragas_score': 0.8068, 'faithfulness': 0.7170, 'answer_relevancy': 0.9224}

# %%
result, result_gpt4
# Out:
# ({'ragas_score': 0.8333, 'faithfulness': 0.7698, 'answer_relevancy': 0.9083},
#  {'ragas_score': 0.8068, 'faithfulness': 0.7170, 'answer_relevancy': 0.9224})

# %%
df = result_gpt4.to_pandas()
result3 = result2.map(
    lambda record, idx: {
        "faithfulness_gpt4": df["faithfulness"][idx], 
        "answer_relevancy_gpt4": df["answer_relevancy"][idx], 
        "ragas_score_gpt4": df["faithfulness"][idx] * df["answer_relevancy"][idx] / (df["faithfulness"][idx] + df["answer_relevancy"][idx])
    },
    batched=False,
    with_indices=True,
)
result3
# Out:
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Dataset({
#     features: ['EM', 'F1', 'faithfulness', 'answer_relevancy', 'ragas_score', 'faithfulness_gpt4', 'answer_relevancy_gpt4', 'ragas_score_gpt4'],
#     num_rows: 30
# })

# %%
result3.to_csv("gpt-3-4.csv.log")
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 3504

# %%
# %%time

result_instruct = evaluate(
    new_ds,
    metrics=[
        faithfulness_instruct,
        answer_relevancy_instruct,
    ],
)

result, result_gpt4, result_instruct
# Out:
# evaluating with [faithfulness]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:11<00:00,  5.81s/it]
# evaluating with [answer_relevancy]
# 100%|██████████| 2/2 [00:44<00:00, 22.08s/it]
# CPU times: user 238 ms, sys: 82.4 ms, total: 321 ms
# Wall time: 56.3 s
# ({'ragas_score': 0.8333, 'faithfulness': 0.7698, 'answer_relevancy': 0.9083},
#  {'ragas_score': 0.8068, 'faithfulness': 0.7170, 'answer_relevancy': 0.9224},
#  {'ragas_score': 0.8158, 'faithfulness': 0.7474, 'answer_relevancy': 0.8980})

# %%
df = result_instruct.to_pandas()
result_all = result3.map(
    lambda record, idx: {
        "faithfulness_gpt3_instruct": df["faithfulness"][idx], 
        "answer_relevancy_gpt3_instruct": df["answer_relevancy"][idx], 
        "ragas_score_gpt3_instruct": df["faithfulness"][idx] * df["answer_relevancy"][idx] / (df["faithfulness"][idx] + df["answer_relevancy"][idx])
    },
    batched=False,
    with_indices=True,
)
result_all
# Out:
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Dataset({
#     features: ['EM', 'F1', 'faithfulness', 'answer_relevancy', 'ragas_score', 'faithfulness_gpt4', 'answer_relevancy_gpt4', 'ragas_score_gpt4', 'faithfulness_gpt3_instruct', 'answer_relevancy_gpt3_instruct', 'ragas_score_gpt3_instruct'],
#     num_rows: 30
# })

# %%
result_all.to_csv("result_all.csv.log")
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 4885

# %%
df = result_all.to_pandas()
df
# Out:
#     EM        F1  faithfulness  answer_relevancy  ragas_score  \
# 0    1  1.000000      0.666667          0.821788     0.368072
# 1    1  1.000000      1.000000          0.844772     0.457928
# 2    1  1.000000      0.857143          0.777502     0.407691
# 3    1  1.000000      1.000000          0.813215     0.448493
# 4    1  1.000000      0.666667          0.769605     0.357223
# 5    0  0.424742      1.000000          0.949131     0.486951
# 6    0  0.226087      1.000000          0.916488     0.478212
# 7    0  0.161850      0.800000          0.904527     0.424529
# 8    0  0.186528      0.600000          0.976848     0.371697
# 9    0  0.214286      0.500000          0.962691     0.329082
# 10   0  0.199367      1.000000          0.913416     0.477375
# 11   0  0.202381      0.200000          0.954900     0.165365
# 12   0  0.356436      1.000000          0.951978     0.487699
# 13   0  0.383495      1.000000          0.977373     0.494278
# 14   0  0.671642      1.000000          0.919864     0.479130
# 15   0  0.331288      0.666667          0.994253     0.399077
# 16   0  0.419753      1.000000          0.854985     0.460912
# 17   0  0.110687      0.666667          0.894678     0.382012
# 18   0  0.596273      1.000000          0.856767     0.461429
# 19   0  0.267606      0.500000          0.934819     0.325762
# 20   0  0.175258      0.500000          0.863841     0.316694
# 21   0  0.353982      0.666667          0.964975     0.394276
# 22   0  0.423913      0.800000          0.811748     0.402916
# 23   0  0.219780      0.285714          0.962229     0.220301
# 24   0  0.443114      1.000000          0.927224     0.481119
# 25   0  0.276596      0.800000          0.974189     0.439272
# 26   0  0.214000      1.000000          0.938227     0.484065
# 27   0  0.225352      0.666667          0.876366     0.378634
# 28   0  0.054054      1.000000          0.993498     0.498369
# 29   0  0.185907      0.250000          0.946056     0.197745
#
#     faithfulness_gpt4  answer_relevancy_gpt4  ragas_score_gpt4  \
# 0            0.900000               0.827230          0.431041
# 1            0.888889               0.876646          0.441362
# 2            1.000000               0.776124          0.436976
# 3            1.000000               0.852873          0.460297
# 4            0.000000               0.846600          0.000000
# 5            1.000000               0.957010          0.489016
# 6            0.666667               0.965547          0.394371
# 7            0.750000               0.907683          0.410671
# 8            1.000000               0.986572          0.496620
# 9            0.666667               0.931343          0.388543
# 10           0.833333               0.919859          0.437230
# 11           0.800000               0.967975          0.438004
# 12           0.857143               0.937782          0.447826
# 13           0.800000               0.977384          0.439920
# 14           1.000000               0.945617          0.486024
# 15           1.000000               0.984442          0.496080
# 16           0.800000               0.862036          0.414930
# 17           0.666667               0.909521          0.384692
# 18           1.000000               0.861429          0.462778
# 19           0.333333               0.948893          0.246678
# 20           0.666667               0.882279          0.379733
# 21           0.666667               0.971010          0.395279
# 22           0.833333               0.891990          0.430832
# 23           0.000000               0.959906          0.000000
# 24           1.000000               0.940389          0.484639
# 25           0.714286               0.995394          0.415865
# 26           1.000000               0.944147          0.485636
# 27           0.333333               0.880692          0.241810
# 28           0.000000               0.998679          0.000000
# 29           0.333333               0.965394          0.247780
#
#     faithfulness_gpt3_instruct  answer_relevancy_gpt3_instruct  \
# 0                     0.800000                        0.866893
# 1                     1.000000                        0.833523
# 2                     0.888889                        0.776325
# 3                     1.000000                        0.832488
# 4                     0.000000                        0.841671
# 5                     0.333333                        0.930778
# 6                     0.500000                        0.900254
# 7                     0.750000                        0.852995
# 8                     0.500000                        0.923212
# 9                     0.500000                        0.902026
# 10                    1.000000                        0.938420
# 11                    1.000000                        0.921358
# 12                    1.000000                        0.925646
# 13                    1.000000                        0.958138
# 14                    1.000000                        0.930464
# 15                    1.000000                        0.907186
# 16                    1.000000                        0.857762
# 17                    0.666667                        0.895015
# 18                    1.000000                        0.852309
# 19                    0.750000                        0.927082
# 20                    1.000000                        0.852266
# 21                    0.000000                        0.947303
# 22                    0.800000                        0.856047
# 23                    0.666667                        0.958726
# 24                    1.000000                        0.918513
# 25                    0.600000                        0.926988
# 26                    1.000000                        0.917522
# 27                    0.666667                        0.860740
# 28                    0.000000                        0.991851
# 29                    1.000000                        0.936975
#
#     ragas_score_gpt3_instruct
# 0                    0.416052
# 1                    0.454602
# 2                    0.414401
# 3                    0.454294
# 4                    0.000000
# 5                    0.245437
# 6                    0.321461
# 7                    0.399094
# 8                    0.324341
# 9                    0.321687
# 10                   0.484116
# 11                   0.479535
# 12                   0.480694
# 13                   0.489311
# 14                   0.481990
# 15                   0.475667
# 16                   0.461718
# 17                   0.382073
# 18                   0.460133
# 19                   0.414596
# 20                   0.460121
# 21                   0.000000
# 22                   0.413538
# 23                   0.393228
# 24                   0.478763
# 25                   0.364242
# 26                   0.478494
# 27                   0.375687
# 28                   0.000000
# 29                   0.483731

# %%
best = df[df.faithfulness + df.faithfulness_gpt4 + df.faithfulness_gpt3_instruct  > 2.9]
best
# Out:
#     EM        F1  faithfulness  answer_relevancy  ragas_score  \
# 3    1  1.000000           1.0          0.813215     0.448493
# 14   0  0.671642           1.0          0.919864     0.479130
# 18   0  0.596273           1.0          0.856767     0.461429
# 24   0  0.443114           1.0          0.927224     0.481119
# 26   0  0.214000           1.0          0.938227     0.484065
#
#     faithfulness_gpt4  answer_relevancy_gpt4  ragas_score_gpt4  \
# 3                 1.0               0.852873          0.460297
# 14                1.0               0.945617          0.486024
# 18                1.0               0.861429          0.462778
# 24                1.0               0.940389          0.484639
# 26                1.0               0.944147          0.485636
#
#     faithfulness_gpt3_instruct  answer_relevancy_gpt3_instruct  \
# 3                          1.0                        0.832488
# 14                         1.0                        0.930464
# 18                         1.0                        0.852309
# 24                         1.0                        0.918513
# 26                         1.0                        0.917522
#
#     ragas_score_gpt3_instruct
# 3                    0.454294
# 14                   0.481990
# 18                   0.460133
# 24                   0.478763
# 26                   0.478494

# %%
len(best)
# Out:
# 5
